# %% [markdown]
# ## 초기 세팅

# %% [markdown]
# ### 마운트 및 클론

# %%
# 이 파일과 드라이브를 연결
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 클론할 빈 폴더로 이동
# %cd /content/drive/MyDrive/oss_git
# Out:
# /content/drive/MyDrive/oss_git

# %%
# git clone하기
# !git clone https://semnisem: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@github.com/WhatIsMethIs/WhatIsMethIs-Model.git
# Out:
# Cloning into 'WhatIsMethIs-Model'...
# remote: Enumerating objects: 31, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 31 (delta 5), reused 18 (delta 2), pack-reused 0
# Receiving objects: 100% (31/31), 54.24 KiB | 895.00 KiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %% [markdown]
# ### 권한 부여

# %%
# clone한 폴더로 이동
# %cd /content/drive/MyDrive/oss_git/WhatIsMethIs-Model
# Out:
# /content/drive/MyDrive/oss_git/WhatIsMethIs-Model

# %%
# !git config --global user.email 'doldori102493@gmail.com'
# !git config --global user.name 'semnisem'

# %% [markdown]
# ### 그냥 여러가지 확인용

# %%
# 원격 저장소 연결해제
# !git remote remove origin

# %%
# 원격 저장소 재연결
# !git remote add origin https://semnisem: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@github.com/WhatIsMethIs/WhatIsMethIs-Model.git

# %%
# 원격 저장소 확인
# !git remote -v
# Out:
# origin	https://semnisem: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@github.com/WhatIsMethIs/WhatIsMethIs-Model.git (fetch)
# origin	https://semnisem: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@github.com/WhatIsMethIs/WhatIsMethIs-Model.git (push)

# %% [markdown]
# ## Commit 시 실행할 코드

# %%
# 구글 드라이브 접근
from google.colab import drive
drive.mount('/content/drive')

# %%
# 커밋을 하고자하는 폴더로 이동
# %cd /content/drive/MyDrive/oss_git/WhatIsMethIs-Model/model
# Out:
# /content/drive/MyDrive/oss_git/WhatIsMethIs-Model/model

# %%
# 본인확인
# !git config --global user.email 'doldori102493@gmail.com'
# !git config --global user.name 'semnisem'

# %%
# add
# !git add .
#!git add .
#!git add --all

# %%
# commit
# !git commit -m 'temp file commit2'
# Out:
# [main 574ce83] temp file commit
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite model/temp_code.ipynb (70%)

# %%
# commit 기록 확인
# !git log

# %%
# push
# !git push -u origin main
# Out:
# Enumerating objects: 10, done.
# Counting objects: 100% (10/10), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (8/8), done.
# Writing objects: 100% (8/8), 1.25 KiB | 142.00 KiB/s, done.
# Total 8 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), done.
# To https://github.com/WhatIsMethIs/WhatIsMethIs-Model.git
#  + 4876069...574ce83 main -> main (forced update)
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# !git push --set-upstream origin main

# %% [markdown]
# ## Pull 시 실행할 코드

# %%
# pull 최초 시, 방식 명시
# !git config --global pull.ff only

# %%
# pull
# !git pull
