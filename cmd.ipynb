# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 드라이브 내 경로로 이동
# %cd /content/drive/MyDrive/oss_drive/
# Out:
# /content/drive/MyDrive/oss_drive

# %%
 # !git clone https://semnisem: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@github.com/WhatIsMethIs/WhatIsMethIs-Model.git
# Out:
# fatal: destination path 'WhatIsMethIs-Model' already exists and is not an empty directory.

# %%
# clone한 repository 내 경로로 이동
# %cd /content/WhatIsMethIs-Model/model
# Out:
# [Errno 2] No such file or directory: 'content/WhatIsMethIs-Model/model'
# /content/drive/MyDrive/oss_drive

# %%
# 원격 레포지토리와 연동
# !git config --global user.email 'doldori102493@gmail.com'
# !git config --global user.name 'semnisem'

# %% [markdown]
# # commit

# %%
# !git add .
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git commit -m ""
